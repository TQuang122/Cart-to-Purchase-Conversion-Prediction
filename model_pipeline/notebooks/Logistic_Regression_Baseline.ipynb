# %%
from feast import FeatureStore
import pandas as pd
import numpy as np
from pathlib import Path

# %%
feature_store_yaml = Path("../../data_pipeline/propensity_feature_store/propensity_features/feature_repo/feature_store.yaml")
store = FeatureStore(repo_path=str(feature_store_yaml.parent), fs_yaml_file=feature_store_yaml)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 store = FeatureStore("../../data_pipeline/propensity_feature_store/propensity_features/feature_repo/feature_store.yaml")
#
# File ~/Library/CloudStorage/GoogleDrive-lethanhquang094@gmail.com/My Drive/FPT/Semester_4/DAP391m/Customer_Purchas_Propensity_Prediction/.venv/lib/python3.11/site-packages/feast/feature_store.py:155, in FeatureStore.__init__(self, repo_path, config, fs_yaml_file)
#     153     self.config = load_repo_config(self.repo_path, fs_yaml_file)
#     154 else:
# --> 155     self.config = load_repo_config(
#     156         self.repo_path, utils.get_default_yaml_file_path(self.repo_path)
#     157     )
#     159 registry_config = self.config.registry
#     160 if registry_config.registry_type == "sql":
#
# ...

# %%
a
